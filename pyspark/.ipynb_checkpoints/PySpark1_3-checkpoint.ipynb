# %% [markdown]
# # Reverse Engineering numpy random data generator

# %% [raw]
# """
# # -------------------------------
# # Function 1: Create data with NumPy
# # -------------------------------
# def generate_linear_dataset(n_samples=100, slope=2.0, bias=5.0, noise_std=1.0):
#     """
#     Generate synthetic linear regression dataset using NumPy.
#     Each row = [X, y]
#     """
#     X = np.random.uniform(0, 10, n_samples)
#     y = slope * X + bias + np.random.normal(0, noise_std, n_samples)
#     return np.column_stack((X, y))
# """

# %%
import numpy as np

# %%
arr1 = np.random.uniform(0,10, 5)

# %%
arr1
# Out:
# array([6.95117665, 6.73388759, 4.57982565, 1.1221985 , 9.24377153])

# %%
arr2 = arr1*2

# %%
arr2
arrfinal = np.column_stack((arr1, arr2))

# %%
def visualize_dataset(dataset, model=None):
    """
    Visualize dataset with optional regression line.
    
    Parameters:
    - dataset: NumPy array with rows [X, y]
    - model: PySpark LinearRegressionModel (optional)
    """
    X = dataset[:, 0]
    y = dataset[:, 1]
    
    plt.scatter(X, y, color="blue", alpha=0.6, label="Data points")
    
    # # If model is provided, plot regression line
    # if model is not None:
    #     y_pred = model.coefficients[0] * X + model.intercept
    #     plt.plot(X, y_pred, color="red", linewidth=2, label=f'Regression Line: y = {model.coefficients[0]:.2f}x + {model.intercept:.2f}')
    #     # plt.plot(X, y_pred, color='red', linewidth=2, 
    #     #      label=f'Regression Line: y = {coefficients[0]:.2f}x + {intercept:.2f}')
    
    plt.xlabel("X (feature)")
    plt.ylabel("y (target)")
    #plt.title("Linear Regression Visualization")
    plt.legend()
    plt.show()

# %%
visualize_dataset(arrfinal)

# %%
arr1 = np.random.uniform(0,10, 15)

# %%
slope = 2.0

# %%
arr2 = arr1 *2

# %%
arr2
# Out:
# array([16.32889518, 14.07110407, 10.69655898,  0.85756303,  1.05264661,
#         7.69763143,  4.45267519,  0.23709938,  0.32646937,  8.2338606 ,
#        12.10277468, 11.83385183,  3.29256272, 14.52163941, 11.50043041])

# %%
arrfinal = np.column_stack((arr1, arr2))

# %%
visualize_dataset(arrfinal)

# %%
arr1 = np.random.uniform(0,10, 15)
slope = 2.0
bias = 5
arr2 = arr1 *slope + bias
arrfinal = np.column_stack((arr1, arr2))
visualize_dataset(arrfinal)

# %%
n_samples = 20
noise_std = 1
arr1 = np.random.uniform(0,10, n_samples)
slope = 2.0
bias = 5
arr2 = arr1 *slope + bias + np.random.normal(0, noise_std, n_samples)
arrfinal = np.column_stack((arr1, arr2))
visualize_dataset(arrfinal)

# %%
def gen_array_lr():
    n_samples = 20
    noise_std = 1
    arr1 = np.random.uniform(0,10, n_samples)
    slope = 2.0
    bias = 5
    arr2 = arr1 *slope + bias + np.random.normal(0, noise_std, n_samples)
    arrfinal = np.column_stack((arr1, arr2))
    return arrfinal

# %%
myarr = gen_array_lr()

# %%
visualize_dataset(myarr)

# %%
def gen_array_lr(n_samples = 20, noise_std = 1,  slope = 2.0, bias = 5):
    arr1 = np.random.uniform(0,10, n_samples)
    arr2 = arr1 *slope + bias + np.random.normal(0, noise_std, n_samples)
    arrfinal = np.column_stack((arr1, arr2))
    return arrfinal

# %%
myarr = gen_array_lr(250, 1.52, 3, -5)
visualize_dataset(myarr)

# %%
def gen_array_lr(n_samples = 20, noise_std = 1,  slope = 2.0, bias = 5):
    arr1 = np.random.uniform(0,10, n_samples)
    arr2 = arr1 *slope + bias + np.random.normal(0, noise_std, n_samples)
    return np.column_stack((arr1, arr2))

myarr = gen_array_lr(100)
visualize_dataset(myarr)

# %% [markdown]
# # Reverse Engineering the fit_model_pyspark
